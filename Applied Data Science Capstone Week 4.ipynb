# %% [markdown]
# **Applied Data Science Capstone Week 4**
#
# The Problem: People are looking to move to Palmyra VA to save money from living in Charlottesville and want to find the area that most closely resembles downtown Charlottesville. Things that most folks like about the downtown center include how close it is, how many restaurants and bars are there, and the average high quality of those places.
#
# The Solution: I am going to first enter the lat/long of a popular residential zone in Palmyra and then use ArcGIS API covering a 20mi radius to identify all of the commercial business zoned areas as they are most likely to contain a high volume of restaurants/bars and reduces the amount of information that needs to be processed. Next, I will break the commercial business zones into 2sqmi sections and query the area in foursquare for the number and rating of venues. I will then average the rating for each 2sqmi area and calculate the distance from the original lat/long. Lastly, I will rank each 2sqmi area based on the total value of the following equation: (# of restaurants and bars/distance) * Avg Rating. The highest-end value should be the location that most resembles downtown Charlottesville.

# %%
# importing and installing needed libraries and APIs
import numpy as np # library for data editing

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# for webscraping import Beautiful Soup 
from bs4 import BeautifulSoup

# import ability to read common online file type
import xml

# !pip install geocoder # required for arcgis queries and fuctions
import geocoder # import geocoder

# !pip install folium
import folium as fol # import folium

# !pip install geopy
import geopy # library for geographic operations
from geopy.geocoders import Nominatim # import Nominatim

print('Libraries installed and imported.')
# Out:
# ERROR: Invalid requirement: '#'
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: branca>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.25.8)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: geopy in c:\programdata\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\programdata\anaconda3\lib\site-packages (from geopy) (1.50)
# Libraries installed and imported.

# %%
CLIENT_ID = '0FKU2JA2QKU2H3VZ3FCL1I4T445LGCCCZIEI4BDWEU0BPVVP' # Foursquare ID
CLIENT_SECRET = 'XK53IJ24QLOVU4NWL5IPBZODH2FL51VV2RIIUE4DRBQ3EUSX' # Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 0FKU2JA2QKU2H3VZ3FCL1I4T445LGCCCZIEI4BDWEU0BPVVP
# CLIENT_SECRET:XK53IJ24QLOVU4NWL5IPBZODH2FL51VV2RIIUE4DRBQ3EUSX

# %%
# using Nominatim to aquire lat long of Palmyra VA for map creation later
city = 'Lake Monticello, Virginia'

geolocator = Nominatim(user_agent="geoapiExercises")
location = geolocator.geocode(city)
city_lat = location.latitude
city_long = location.longitude
# create map of Palmyra VA using latitude and longitude values
map_pal = fol.Map(location=[city_lat, city_long], zoom_start=11)
    
map_pal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# names and plots location on the map.
start_lat = '37.916426'
start_long = '-78.329203'

fol.CircleMarker(
        [start_lat, start_long],
        radius=3,
        color='green',
        fill=True,
        fill_color= 'green',
        fill_opacity=0.3,
        parse_html=False).add_to(map_pal)

map_pal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# number of meters in 20 miles
radius = 32187

# creates client for API calls to Foursquare
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    start_lat, 
    start_long, 
    radius)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=0FKU2JA2QKU2H3VZ3FCL1I4T445LGCCCZIEI4BDWEU0BPVVP&client_secret=XK53IJ24QLOVU4NWL5IPBZODH2FL51VV2RIIUE4DRBQ3EUSX&v=20180605&ll=37.916426,-78.329203&radius=32187'

# %%
# gets business information.
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f44475830e7ef00419a28c3'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 203,
#   'suggestedBounds': {'ne': {'lat': 38.20610928968329,
#     'lng': -77.96269329515329},
#    'sw': {'lat': 37.62674271031671, 'lng': -78.69571270484673}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4f29bf964a5202c0021e3',
#        'name': 'Monticello',
#        'location': {'address': '931 Thomas Jefferson Pkwy',
#         'lat': 38.006029477067266,
#         'lng': -78.45213988513116,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.006029477067266,
#           'lng': -78.45213988513116}],
#         'distance': 14693,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['931 Thomas Jefferson Pkwy',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4f29bf964a5202c0021e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b115faef964a520277b23e3',
#        'name': 'Carter Mountain Orchard',
#        'location': {'address': '1435 Carters Mountain Trail',
#         'lat': 37.99130765246418,
#         'lng': -78.4720632490738,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.99130765246418,
#           'lng': -78.4720632490738}],
#         'distance': 15057,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['1435 Carters Mountain Trail',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d15b941735',
#          'name': 'Farm',
#          'pluralName': 'Farms',
#          'shortName': 'Farm',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/farm_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b115faef964a520277b23e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbf770f98f4952174b8d263',
#        'name': 'Monticello Visitors Center',
#        'location': {'address': '931 Thomas Jefferson Pkwy',
#         'lat': 38.00583388897391,
#         'lng': -78.45202914367397,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.00583388897391,
#           'lng': -78.45202914367397}],
#         'distance': 14672,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['931 Thomas Jefferson Pkwy',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbf770f98f4952174b8d263-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbcfdf7078095215a0bda91',
#        'name': 'Glenmore Country Club',
#        'location': {'address': '1750 Piper Way',
#         'lat': 37.98733734446215,
#         'lng': -78.3865140780268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.98733734446215,
#           'lng': -78.3865140780268}],
#         'distance': 9360,
#         'postalCode': '22947',
#         'cc': 'US',
#         'city': 'Keswick',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['1750 Piper Way',
#          'Keswick, VA 22947',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e6941735',
#          'name': 'Golf Course',
#          'pluralName': 'Golf Courses',
#          'shortName': 'Golf Course',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/golfcourse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbcfdf7078095215a0bda91-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fc56644e4b0d67823a1d534',
#        'name': 'il Castello',
#        'location': {'address': '47 Market St',
#         'lat': 37.978475041012516,
#         'lng': -78.21068524100066,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.978475041012516,
#           'lng': -78.21068524100066}],
#         'distance': 12488,
#         'postalCode': '22942',
#         'cc': 'US',
#         'city': 'Zion Crossroads',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['47 Market St',
#          'Zion Crossroads, VA 22942',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fc56644e4b0d67823a1d534-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b93fb06f964a520b95e34e3',
#        'name': 'Saunders Monticello Trail',
#        'location': {'lat': 38.00285175944515,
#         'lng': -78.47718410885112,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.00285175944515,
#           'lng': -78.47718410885112}],
#         'distance': 16163,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['Charlottesville, VA 22902', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b93fb06f964a520b95e34e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '599c904d947c05572b718fea',
#        'name': "Three Notch'd Craft Kitchen & Brewery",
#        'location': {'address': '520 2nd St SE',
#         'lat': 38.026074882846856,
#         'lng': -78.48202197452854,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.026074882846856,
#           'lng': -78.48202197452854}],
#         'distance': 18133,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['520 2nd St SE',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-599c904d947c05572b718fea-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53e0125b498efd2d6267c676',
#        'name': 'Lampo',
#        'location': {'address': '205 Monticello Rd',
#         'crossStreet': 'Graves St',
#         'lat': 38.02735593321531,
#         'lng': -78.47690700598577,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.02735593321531,
#           'lng': -78.47690700598577}],
#         'distance': 17902,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['205 Monticello Rd (Graves St)',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '95778042'}},
#       'referralId': 'e-0-53e0125b498efd2d6267c676-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc789a82f94d13a181d127f',
#        'name': 'Blenheim Vineyards',
#        'location': {'address': '31 Blenheim Farm',
#         'lat': 37.93165597152479,
#         'lng': -78.49887185955836,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.93165597152479,
#           'lng': -78.49887185955836},
#          {'label': 'entrance', 'lat': 37.931858, 'lng': -78.499192}],
#         'distance': 14994,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['31 Blenheim Farm',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14b941735',
#          'name': 'Winery',
#          'pluralName': 'Wineries',
#          'shortName': 'Winery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc789a82f94d13a181d127f-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '563cafa8cd1088eed1c78179',
#        'name': 'Chick-fil-A',
#        'location': {'address': '1626 Richmond Rd',
#         'lat': 38.029109,
#         'lng': -78.440447,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.029109,
#           'lng': -78.440447}],
#         'distance': 15894,
#         'postalCode': '22911',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['1626 Richmond Rd',
#          'Charlottesville, VA 22911',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2038922',
#         'url': 'https://www.grubhub.com/restaurant/chick-fil-a-1626-richmond-rd-charlottesville/2038922?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2038922',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-563cafa8cd1088eed1c78179-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5301802c498e78c43fb3edf1',
#        'name': 'Public Fish & Oyster',
#        'location': {'address': '513 W Main St',
#         'lat': 38.031137526898476,
#         'lng': -78.48831364920228,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.031137526898476,
#           'lng': -78.48831364920228},
#          {'label': 'entrance', 'lat': 38.031147, 'lng': -78.488231}],
#         'distance': 18921,
#         'postalCode': '22903',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['513 W Main St',
#          'Charlottesville, VA 22903',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5301802c498e78c43fb3edf1-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8ead4df964a5204f3033e3',
#        'name': 'Michie Tavern',
#        'location': {'address': '683 Thomas Jefferson Pkwy',
#         'lat': 38.00882757963886,
#         'lng': -78.46367342670005,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.00882757963886,
#           'lng': -78.46367342670005}],
#         'distance': 15655,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['683 Thomas Jefferson Pkwy',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '73669930'}},
#       'referralId': 'e-0-4b8ead4df964a5204f3033e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bba119f7421a5937656c340',
#        'name': 'Charlottesville Historic Downtown Mall',
#        'location': {'address': 'Main St',
#         'crossStreet': 'btwn Water & Market St',
#         'lat': 38.030383637581394,
#         'lng': -78.4803808016092,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.030383637581394,
#           'lng': -78.4803808016092}],
#         'distance': 18355,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['Main St (btwn Water & Market St)',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bba119f7421a5937656c340-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5382568f498e151a051d4ca8',
#        'name': 'Pavillion IX Art Park',
#        'location': {'lat': 38.025859909996704,
#         'lng': -78.48225716608056,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.025859909996704,
#           'lng': -78.48225716608056}],
#         'distance': 18132,
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['Charlottesville, VA', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5382568f498e151a051d4ca8-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54d29297498e4e44a7775503',
#        'name': "Jack Brown's Beer & Burger Joint",
#        'location': {'address': '109 2nd St SE',
#         'crossStreet': 'Water St.',
#         'lat': 38.03015706722324,
#         'lng': -78.48106149173974,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.03015706722324,
#           'lng': -78.48106149173974}],
#         'distance': 18381,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['109 2nd St SE (Water St.)',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2039023',
#         'url': 'https://www.grubhub.com/restaurant/jack-browns-beer--burger-joint-109-2nd-st-se-charlottesville/2039023?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2039023',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54d29297498e4e44a7775503-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50b0116ce4b042e780e57226',
#        'name': 'Champion Brewery',
#        'location': {'address': '324 6th St SE',
#         'lat': 38.02786317558847,
#         'lng': -78.47835650885982,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.02786317558847,
#           'lng': -78.47835650885982}],
#         'distance': 18033,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['324 6th St SE',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50b0116ce4b042e780e57226-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b81b72ef964a52096b930e3',
#        'name': 'The Paramount',
#        'location': {'address': '215 E Main St',
#         'crossStreet': 'Downtown Mall',
#         'lat': 38.03095515399864,
#         'lng': -78.479909724953,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.03095515399864,
#           'lng': -78.479909724953},
#          {'label': 'entrance', 'lat': 38.030501, 'lng': -78.480276}],
#         'distance': 18369,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['215 E Main St (Downtown Mall)',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b81b72ef964a52096b930e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5033aaa4e4b0488f309af061',
#        'name': 'Ace Biscuit & Barbecue',
#        'location': {'address': '711 Henry Ave',
#         'lat': 38.03755454222439,
#         'lng': -78.4831953048706,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 38.037995,
#           'lng': -78.484526},
#          {'label': 'display',
#           'lat': 38.03755454222439,
#           'lng': -78.4831953048706}],
#         'distance': 19089,
#         'postalCode': '22903',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['711 Henry Ave',
#          'Charlottesville, VA 22903',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5033aaa4e4b0488f309af061-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5816668bd67ca503886e0ded',
#        'name': 'Wegmans',
#        'location': {'address': '100 Wegmans Way',
#         'lat': 38.00894235015678,
#         'lng': -78.5003881506967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.00894235015678,
#           'lng': -78.5003881506967},
#          {'label': 'entrance', 'lat': 38.008763, 'lng': -78.500484}],
#         'distance': 18215,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['100 Wegmans Way',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5816668bd67ca503886e0ded-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5575c3c1498e6be26ae3cddb',
#        'name': 'Brazos Tacos',
#        'location': {'address': '925 2nd St SE',
#         'lat': 38.02486154207102,
#         'lng': -78.4830210691752,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.02486154207102,
#           'lng': -78.4830210691752}],
#         'distance': 18108,
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['925 2nd St SE',
#          'Charlottesville, VA',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5575c3c1498e6be26ae3cddb-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4afdf5a7f964a5206d2c22e3',
#        'name': 'The Local',
#        'location': {'address': '824 Hinton Ave',
#         'lat': 38.02467113332398,
#         'lng': -78.4754548024364,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.02467113332398,
#           'lng': -78.4754548024364},
#          {'label': 'entrance', 'lat': 38.024601, 'lng': -78.475476}],
#         'distance': 17604,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['824 Hinton Ave',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4afdf5a7f964a5206d2c22e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be4fe0b2457a5934312ab15',
#        'name': 'Mas',
#        'location': {'address': '904 Monticello Rd',
#         'lat': 38.024274468016415,
#         'lng': -78.4743862049492,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.024274468016415,
#           'lng': -78.4743862049492},
#          {'label': 'entrance', 'lat': 38.024125, 'lng': -78.474366}],
#         'distance': 17505,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['904 Monticello Rd',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be4fe0b2457a5934312ab15-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b53bbe9f964a520a0a927e3',
#        'name': 'Tavola',
#        'location': {'address': '826 Hinton Ave',
#         'lat': 38.02456047471409,
#         'lng': -78.47540767205305,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.02456047471409,
#           'lng': -78.47540767205305}],
#         'distance': 17593,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['826 Hinton Ave',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b53bbe9f964a520a0a927e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6b514af964a52083002ce3',
#        'name': 'Feast!',
#        'location': {'address': '416 W Main St',
#         'lat': 38.03056115498087,
#         'lng': -78.4869745155007,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.03056115498087,
#           'lng': -78.4869745155007},
#          {'label': 'entrance', 'lat': 38.030607, 'lng': -78.487246}],
#         'distance': 18791,
#         'postalCode': '22903',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['416 W Main St',
#          'Charlottesville, VA 22903',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6b514af964a52083002ce3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb757c9ef159c749a0b77f7',
#        'name': 'Charlottesville City Market',
#        'location': {'address': '212 2nd St SW',
#         'lat': 38.02982644402836,
#         'lng': -78.48165080193068,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.02982644402836,
#           'lng': -78.48165080193068}],
#         'distance': 18393,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['212 2nd St SW',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb757c9ef159c749a0b77f7-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b19dbe2f964a52061e523e3',
#        'name': 'The Jefferson Theater',
#        'location': {'address': '110 E Main St',
#         'crossStreet': 'Downtown Mall',
#         'lat': 38.030066616289275,
#         'lng': -78.48153381949933,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.030066616289275,
#           'lng': -78.48153381949933}],
#         'distance': 18404,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['110 E Main St (Downtown Mall)',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '41552141'}},
#       'referralId': 'e-0-4b19dbe2f964a52061e523e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf7b7845efe2d7fa86c6934',
#        'name': 'Riverview Park',
#        'location': {'address': 'Chesapeake St & Riverside Ave',
#         'lat': 38.023985718117075,
#         'lng': -78.4547931450592,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.023985718117075,
#           'lng': -78.4547931450592}],
#         'distance': 16273,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['Chesapeake St & Riverside Ave',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf7b7845efe2d7fa86c6934-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1b1b0cf964a52024f823e3',
#        'name': "Splendora's Gelato",
#        'location': {'address': '317 E Main St',
#         'crossStreet': 'Downtown Mall at 4th NE',
#         'lat': 38.030244785735825,
#         'lng': -78.4795988006552,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.030244785735825,
#           'lng': -78.4795988006552},
#          {'label': 'entrance', 'lat': 38.030272, 'lng': -78.479558}],
#         'distance': 18295,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['317 E Main St (Downtown Mall at 4th NE)',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1b1b0cf964a52024f823e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b475a0df964a5208e2f26e3',
#        'name': 'ACAC Downtown',
#        'location': {'address': '111 Monticello Ave',
#         'crossStreet': 'at 2nd St. SE',
#         'lat': 38.02816165834478,
#         'lng': -78.48330059390047,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.02816165834478,
#           'lng': -78.48330059390047},
#          {'label': 'entrance', 'lat': 38.027979, 'lng': -78.483447}],
#         'distance': 18373,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['111 Monticello Ave (at 2nd St. SE)',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b475a0df964a5208e2f26e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52f1654c11d21fc7673a8964',
#        'name': 'The Alley Light',
#        'location': {'address': '108 2nd St SW',
#         'lat': 38.030546233154624,
#         'lng': -78.48236566503455,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.030546233154624,
#           'lng': -78.48236566503455},
#          {'label': 'entrance', 'lat': 38.030712, 'lng': -78.482333}],
#         'distance': 18493,
#         'postalCode': '22902',
#         'cc': 'US',
#         'city': 'Charlottesville',
#         'state': 'VA',
#         'country': 'United States',
#         'formattedAddress': ['108 2nd St SW',
#          'Charlottesville, VA 22902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d4941735',
#          'name': 'Speakeasy',
#          'pluralName': 'Speakeasies',
#          'shortName': 'Speakeasy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/secretbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52f1654c11d21fc7673a8964-29'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                       name               categories  \
# 0                               Monticello            Historic Site
# 1                  Carter Mountain Orchard                     Farm
# 2               Monticello Visitors Center           History Museum
# 3                    Glenmore Country Club              Golf Course
# 4                              il Castello       Italian Restaurant
# 5                Saunders Monticello Trail                    Trail
# 6    Three Notch'd Craft Kitchen & Brewery                  Brewery
# 7                                    Lampo              Pizza Place
# 8                       Blenheim Vineyards                   Winery
# 9                              Chick-fil-A     Fast Food Restaurant
# 10                    Public Fish & Oyster       Seafood Restaurant
# 11                           Michie Tavern      American Restaurant
# 12  Charlottesville Historic Downtown Mall            Shopping Mall
# 13                   Pavillion IX Art Park                     Park
# 14        Jack Brown's Beer & Burger Joint             Burger Joint
# 15                        Champion Brewery                  Brewery
# 16                           The Paramount              Music Venue
# 17                  Ace Biscuit & Barbecue                BBQ Joint
# 18                                 Wegmans              Supermarket
# 19                            Brazos Tacos               Taco Place
# 20                               The Local  New American Restaurant
# 21                                     Mas         Tapas Restaurant
# 22                                  Tavola       Italian Restaurant
# 23                                  Feast!             Gourmet Shop
# 24             Charlottesville City Market           Farmers Market
# 25                   The Jefferson Theater              Music Venue
# 26                          Riverview Park                     Park
# 27                      Splendora's Gelato             Dessert Shop
# 28                           ACAC Downtown     Gym / Fitness Center
# 29                         The Alley Light                Speakeasy
#
#           lat        lng
# 0   38.006029 -78.452140
# 1   37.991308 -78.472063
# 2   38.005834 -78.452029
# 3   37.987337 -78.386514
# 4   37.978475 -78.210685
# 5   38.002852 -78.477184
# 6   38.026075 -78.482022
# 7   38.027356 -78.476907
# 8   37.931656 -78.498872
# 9   38.029109 -78.440447
# 10  38.031138 -78.488314
# 11  38.008828 -78.463673
# 12  38.030384 -78.480381
# 13  38.025860 -78.482257
# 14  38.030157 -78.481061
# 15  38.027863 -78.478357
# 16  38.030955 -78.479910
# 17  38.037555 -78.483195
# 18  38.008942 -78.500388
# 19  38.024862 -78.483021
# 20  38.024671 -78.475455
# 21  38.024274 -78.474386
# 22  38.024560 -78.475408
# 23  38.030561 -78.486975
# 24  38.029826 -78.481651
# 25  38.030067 -78.481534
# 26  38.023986 -78.454793
# 27  38.030245 -78.479599
# 28  38.028162 -78.483301
# 29  38.030546 -78.482366

# %%
# plots locations in table to the map in red
for lat, lng in zip(nearby_venues['lat'], nearby_venues['lng']):
    fol.CircleMarker(
        [lat, lng],
        radius=3,
        color='red',
        fill=True,
        fill_color= 'red',
        fill_opacity=0.3,
        parse_html=False).add_to(map_pal)

map_pal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
venue_cluster = nearby_venues[['lat', 'lng']]
venue_cluster = StandardScaler().fit_transform(venue_cluster)

db = DBSCAN(eps=0.3, min_samples=4).fit(venue_cluster)
core = np.zeros_like(db.labels_, dtype=bool)
core[db.core_sample_indices_] = True
labels = db.labels_
print (labels[500:500])
nearby_venues["DB_Cluster"] = labels

cluster_count = len(set(labels)) - (1 if -1 in labels else 0)
noise_count = list(labels).count(-1)

print('Estimated number of clusters: %d' % cluster_count)
print('Estimated number of noise points: %d' % noise_count)
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
print("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(labels_true, labels))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(labels_true, labels))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(venue_cluster, labels))
# Out:
# []
# Estimated number of clusters: 1
# Estimated number of noise points: 12
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b1d169d01341> in <module>
#      18 print('Estimated number of clusters: %d' % cluster_count)
#      19 print('Estimated number of noise points: %d' % noise_count)
# ---> 20 print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
#      21 print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
#      22 print("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
#
# NameError: name 'labels_true' is not defined
